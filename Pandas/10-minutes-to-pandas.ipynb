# %% [markdown]
# http://pandas.pydata.org/pandas-docs/stable/10min.html

# %% [markdown]
# # 10 Minutes to pandas
#
# This is a short introduction to pandas, geared mainly for new users. You can see more complex recipes in the [Cookbook](http://pandas.pydata.org/pandas-docs/stable/cookbook.html#cookbook)

# %% [markdown]
# Customarily, we import as follows:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !wget https://www.dropbox.com/s/8grgwn4b6y25frw/titanic.csv
data = pd.read_csv('titanic.csv')
# Out:
# --2019-01-20 21:33:12--  https://www.dropbox.com/s/8grgwn4b6y25frw/titanic.csv
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.1, 2620:100:601b:1::a27d:801
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/8grgwn4b6y25frw/titanic.csv [following]
# --2019-01-20 21:33:13--  https://www.dropbox.com/s/raw/8grgwn4b6y25frw/titanic.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc9a3e640215fd036cbcfcb1e22c.dl.dropboxusercontent.com/cd/0/inline/AZyiU9uMPd00xB47Rghmflz2BJpYQqjGoyVxpAQ1kLKeA2xl_xSL6auidx_P6TQqJ3FNuVqsG_OCVi74jc6xVOf0SzIxriY3K1ISxHHqcCBL6tuy0ClDhxYnUUL7oky1ePOa-_brcwyjxEPPVbBXfqMWTfB-y-4WM4-F50s1U6d_onGO7UXGeaoLYdGqKdPE2dM/file# [following]
# --2019-01-20 21:33:13--  https://uc9a3e640215fd036cbcfcb1e22c.dl.dropboxusercontent.com/cd/0/inline/AZyiU9uMPd00xB47Rghmflz2BJpYQqjGoyVxpAQ1kLKeA2xl_xSL6auidx_P6TQqJ3FNuVqsG_OCVi74jc6xVOf0SzIxriY3K1ISxHHqcCBL6tuy0ClDhxYnUUL7oky1ePOa-_brcwyjxEPPVbBXfqMWTfB-y-4WM4-F50s1U6d_onGO7UXGeaoLYdGqKdPE2dM/file
# Resolving uc9a3e640215fd036cbcfcb1e22c.dl.dropboxusercontent.com (uc9a3e640215fd036cbcfcb1e22c.dl.dropboxusercontent.com)... 162.125.8.6, 2620:100:601a:6::a27d:706
# Connecting to uc9a3e640215fd036cbcfcb1e22c.dl.dropboxusercontent.com (uc9a3e640215fd036cbcfcb1e22c.dl.dropboxusercontent.com)|162.125.8.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60302 (59K) [text/plain]
# Saving to: ‘titanic.csv’
#
# titanic.csv         100%[===================>]  58.89K  --.-KB/s    in 0.1s
#
# 2019-01-20 21:33:13 (580 KB/s) - ‘titanic.csv’ saved [60302/60302]

# %%
# %matplotlib inline

# %% [markdown]
# ## Object Creation
#
# See the [Data Structure Intro section](http://pandas.pydata.org/pandas-docs/stable/dsintro.html#dsintro)

# %% [markdown]
# Creating a Series by passing a list of values, letting pandas create a default integer index:

# %%
s = pd.Series([1,3,5,np.nan,6,8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# Creating a DataFrame by passing a numpy array, with a datetime index and labeled columns:

# %%
dates = pd.date_range('20130101', periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
list('ABCD')
# Out:
# ['A', 'B', 'C', 'D']

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.675124 -0.065441 -0.689620 -0.168304
# 2013-01-02  1.332647  0.052685 -0.022790 -0.557242
# 2013-01-03 -1.100042 -0.538064 -0.159699 -0.898182
# 2013-01-04  0.852773 -0.688149 -0.341586  0.715443
# 2013-01-05  0.592691  0.571501  1.371080 -0.063149
# 2013-01-06  0.589259  0.133742 -1.300138 -0.640481

# %% [markdown]
# Creating a DataFrame by passing a dict of objects that can be converted to series-like.

# %%
df2 = pd.DataFrame({'A':1.,
                   'B':pd.Timestamp('20130102'),
                   'C':pd.Series(1,index=list(range(5)),dtype='float32'),
                   'D':np.array([3]*5,dtype='int32'),
                   'E':pd.Categorical(["test","train","test","train","five"]),
                   'F':'foo'})
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo
# 4  1.0 2013-01-02  1.0  3   five  foo

# %%
df2
# Out:
#      A          B    C  D      E    F
# 3  1.0 2013-01-02  1.0  3   test  foo
# 4  1.0 2013-01-02  1.0  3  train  foo
# 5  1.0 2013-01-02  1.0  3   test  foo
# 6  1.0 2013-01-02  1.0  3  train  foo

# %% [markdown]
# Having specific [dtypes](http://pandas.pydata.org/pandas-docs/stable/basics.html#basics-dtypes)

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# If you’re using IPython, tab completion for column names (as well as public attributes) is automatically enabled. Here’s a subset of the attributes that will be completed:

# %%
# df2.<TAB>

# %%
df2.head()

# %% [markdown]
# As you can see, the columns A, B, C, and D are automatically tab completed. E is there as well; the rest of the attributes have been truncated for brevity.

# %%
data.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## Viewing Data
#
# See the [Basics section](http://pandas.pydata.org/pandas-docs/stable/basics.html#basics)

# %% [markdown]
# See the top & bottom rows of the frame

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01 -0.675124 -0.065441 -0.689620 -0.168304
# 2013-01-02  1.332647  0.052685 -0.022790 -0.557242
# 2013-01-03 -1.100042 -0.538064 -0.159699 -0.898182
# 2013-01-04  0.852773 -0.688149 -0.341586  0.715443
# 2013-01-05  0.592691  0.571501  1.371080 -0.063149

# %%
df.A
# Out:
# 2013-01-01   -0.675124
# 2013-01-02    1.332647
# 2013-01-03   -1.100042
# 2013-01-04    0.852773
# 2013-01-05    0.592691
# 2013-01-06    0.589259
# Freq: D, Name: A, dtype: float64

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04  0.852773 -0.688149 -0.341586  0.715443
# 2013-01-05  0.592691  0.571501  1.371080 -0.063149
# 2013-01-06  0.589259  0.133742 -1.300138 -0.640481

# %% [markdown]
# Display the index, columns, and the underlying numpy data

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index([u'A', u'B', u'C', u'D'], dtype='object')

# %%
df.columns = ['X', 'Y', "Z", "L"]

# %%
df.head()
# Out:
#                    X         Y         Z         L
# 2013-01-01 -0.675124 -0.065441 -0.689620 -0.168304
# 2013-01-02  1.332647  0.052685 -0.022790 -0.557242
# 2013-01-03 -1.100042 -0.538064 -0.159699 -0.898182
# 2013-01-04  0.852773 -0.688149 -0.341586  0.715443
# 2013-01-05  0.592691  0.571501  1.371080 -0.063149

# %%
df[['X','Y']]
# Out:
#                    X         Y
# 2013-01-01 -0.659391 -0.752060
# 2013-01-02 -1.477392 -0.688350
# 2013-01-03  0.573114 -0.237978
# 2013-01-04  0.101939  0.749480
# 2013-01-05  0.418279 -0.158822
# 2013-01-06 -2.210900 -2.232787

# %%
df.values
# Out:
# array([[-0.65939102, -0.75206013,  2.296618  ,  0.38540103],
#        [-1.47739192, -0.68835004,  0.48806622, -0.14273224],
#        [ 0.5731136 , -0.23797777, -1.10637108,  0.91071775],
#        [ 0.10193924,  0.74948026,  0.70014131,  0.16648245],
#        [ 0.41827918, -0.15882206, -0.37662979, -1.27939514],
#        [-2.21090044, -2.23278694, -0.6560063 , -0.28746947]])

# %% [markdown]
# Describe shows a quick statistic summary of your data

# %%
df.describe()

# %% [markdown]
# Transposing your data

# %%
df.T

# %% [markdown]
# Sorting by an axis

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    Z         Y         X         L
# 2013-01-01  2.296618 -0.752060 -0.659391  0.385401
# 2013-01-02  0.488066 -0.688350 -1.477392 -0.142732
# 2013-01-03 -1.106371 -0.237978  0.573114  0.910718
# 2013-01-04  0.700141  0.749480  0.101939  0.166482
# 2013-01-05 -0.376630 -0.158822  0.418279 -1.279395
# 2013-01-06 -0.656006 -2.232787 -2.210900 -0.287469

# %% [markdown]
# Sorting by value

# %%
df.sort_values(by='B')

# %% [markdown]
# ## Selection

# %% [markdown]
# **Note:** While standard Python / Numpy expressions for selecting and setting are intuitive and come in handy for interactive work, for production code, we recommend the optimized pandas data access methods, .at, .iat, .loc, .iloc and .ix.

# %% [markdown]
# See the indexing documentation [Indexing and Selecting Data](http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing) and [MultiIndex / Advanced Indexing](http://pandas.pydata.org/pandas-docs/stable/advanced.html#advanced)

# %% [markdown]
# ### Getting

# %% [markdown]
# Selecting a single column, which yields a Series, equivalent to df.A

# %%
df['A']
# Out:
# 2013-01-01   -0.873730
# 2013-01-02    1.922248
# 2013-01-03    0.465146
# 2013-01-04    0.242522
# 2013-01-05    0.775735
# 2013-01-06    0.805438
# Freq: D, Name: A, dtype: float64

# %% [markdown]
# Selecting via [], which slices the rows.

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01 -0.873730 -0.313265 -0.948619 -0.945572
# 2013-01-02  1.922248 -0.163636 -0.996819 -0.161202
# 2013-01-03  0.465146 -1.556143  0.543273 -0.039261

# %%
df['20130101':'20130104']
# Out:
#                    X         Y         Z         L
# 2013-01-01 -0.675124 -0.065441 -0.689620 -0.168304
# 2013-01-02  1.332647  0.052685 -0.022790 -0.557242
# 2013-01-03 -1.100042 -0.538064 -0.159699 -0.898182
# 2013-01-04  0.852773 -0.688149 -0.341586  0.715443

# %% [markdown]
# ### Selection by Label
#
# See more in [Selection by Label](Selection by Label)

# %% [markdown]
# For getting a cross section using a label

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.loc[dates[0]]
# Out:
# A   -0.873730
# B   -0.313265
# C   -0.948619
# D   -0.945572
# Name: 2013-01-01 00:00:00, dtype: float64

# %% [markdown]
# Selection by Label

# %%
df.loc['20130101':'20130104',['X','Y']]
# Out:
#                    X         Y
# 2013-01-01 -0.675124 -0.065441
# 2013-01-02  1.332647  0.052685
# 2013-01-03 -1.100042 -0.538064
# 2013-01-04  0.852773 -0.688149

# %% [markdown]
# Showing label slicing, both endpoints are included

# %%
df.loc['20130102':'20130104',['X','Y']]
# Out:
#                    X         Y
# 2013-01-02  1.332647  0.052685
# 2013-01-03 -1.100042 -0.538064
# 2013-01-04  0.852773 -0.688149

# %% [markdown]
# Reduction in the dimensions of the returned object

# %%
df.loc['20130102',['A','B']]
# Out:
# A    1.922248
# B   -0.163636
# Name: 2013-01-02 00:00:00, dtype: float64

# %% [markdown]
# For getting a scalar value

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.loc[dates[0],'A']
# Out:
# -0.8737302352101003

# %% [markdown]
# ### Selection by Position
#
# See more in [Selection by Position](http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-integer)

# %% [markdown]
# Select via the position of the passed integers

# %%
df.iloc[3]
# Out:
# A    0.242522
# B    0.402289
# C    0.931186
# D    0.418055
# Name: 2013-01-04 00:00:00, dtype: float64

# %% [markdown]
# By integer slices, acting similar to numpy/python

# %%
df.iloc[3:5,0:2]
# Out:
#                    A         B
# 2013-01-04  0.242522  0.402289
# 2013-01-05  0.775735  0.927382

# %% [markdown]
# By lists of integer position locations, similar to the numpy/python style

# %%
df.iloc[[1,2,4],[0,2]]
# Out:
#                    X         Z
# 2013-01-02  1.332647 -0.022790
# 2013-01-03 -1.100042 -0.159699
# 2013-01-05  0.592691  1.371080

# %% [markdown]
# For slicing rows explicitly

# %%
df.iloc[1:3,:]
# Out:
#                    A         B         C         D
# 2013-01-02  1.922248 -0.163636 -0.996819 -0.161202
# 2013-01-03  0.465146 -1.556143  0.543273 -0.039261

# %% [markdown]
# For slicing columns explicitly

# %%
df.iloc[:,1:3]
# Out:
#                    B         C
# 2013-01-01 -0.313265 -0.948619
# 2013-01-02 -0.163636 -0.996819
# 2013-01-03 -1.556143  0.543273
# 2013-01-04  0.402289  0.931186
# 2013-01-05  0.927382  0.460234
# 2013-01-06  0.816000  0.444233

# %% [markdown]
# For getting a value explicitly

# %%
df.iloc[1,1]

# %% [markdown]
# For getting fast access to a scalar (equiv to the prior method)

# %%
df.iat[1,1]
# Out:
# -0.16363550619697376

# %% [markdown]
# ## Boolean Indexing

# %% [markdown]
# Using a single column’s values to select data.

# %%
tmp = df[['B','C']]

# %%
tmp.loc['2013-01-02']['B'] = 555

# %%
tmp
# Out:
#                      B         C
# 2013-01-01   -0.313265 -0.948619
# 2013-01-02  555.000000 -0.996819
# 2013-01-03   -1.556143  0.543273
# 2013-01-04    0.402289  0.931186
# 2013-01-05    0.927382  0.460234
# 2013-01-06    0.816000  0.444233

# %%
df.columns = list("ABCD")

# %%
df[[True,False,True,False,True,False]].['A',"B"]
# Out:
#   File "<ipython-input-54-a259064317ac>", line 1
#     df[[True,False,True,False,True,False]].['A',"B"]
#                                            ^
# SyntaxError: invalid syntax

# %%
df[df.A > 0]
# Out:
#                    A         B         C         D
# 2013-01-02  1.922248 -0.163636 -0.996819 -0.161202
# 2013-01-03  0.465146 -1.556143  0.543273 -0.039261
# 2013-01-04  0.242522  0.402289  0.931186  0.418055
# 2013-01-05  0.775735  0.927382  0.460234  1.822003
# 2013-01-06  0.805438  0.816000  0.444233  0.703847

# %% [markdown]
# A where operation for getting.

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01       NaN       NaN       NaN       NaN
# 2013-01-02  1.922248       NaN       NaN       NaN
# 2013-01-03  0.465146       NaN  0.543273       NaN
# 2013-01-04  0.242522  0.402289  0.931186  0.418055
# 2013-01-05  0.775735  0.927382  0.460234  1.822003
# 2013-01-06  0.805438  0.816000  0.444233  0.703847

# %% [markdown]
# Using the isin() method for filtering:

# %%
df2 = df.copy()

# %%
df2['E'] = ['one','one', 'two','three','four','three']

# %%
df2

# %%
df2[df2['E'].isin(['two','four'])]

# %% [markdown]
# ## Setting

# %% [markdown]
# Setting a new column automatically aligns the data by the indexes

# %%
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range('20130102',periods=6))

# %%
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df['F'] = s1

# %% [markdown]
# Setting values by label

# %%
df.at[dates[0],'A'] = 0

# %% [markdown]
# Settomg values by position

# %%
df.iat[0,1] = 0

# %% [markdown]
# Setting by assigning with a numpy array

# %%
df.loc[:,'D'] = np.array([5] * len(df))

# %% [markdown]
# The result of the prior setting operations

# %%
df

# %% [markdown]
# A where operation with setting.

# %%
df2 = df.copy()

# %%
df2[df2 > 0] = -df2

# %%
df2

# %% [markdown]
# ## Missing Data
#
# pandas primarily uses the value np.nan to represent missing data. It is by default not included in computations. See the Missing Data section

# %% [markdown]
# Reindexing allows you to change/add/delete the index on a specified axis. This returns a copy of the data.

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])

# %%
df1.loc[dates[0]:dates[1],'E'] = 1

# %%
df1
# Out:
#                    A         B         C         D    E
# 2013-01-01 -0.675124 -0.065441 -0.689620 -0.168304  1.0
# 2013-01-02  1.332647  0.052685 -0.022790 -0.557242  1.0
# 2013-01-03 -1.100042 -0.538064 -0.159699 -0.898182  NaN
# 2013-01-04  0.852773 -0.688149 -0.341586  0.715443  NaN

# %% [markdown]
# To drop any rows that have missing data.

# %%
df1.dropna(how='any')
# Out:
#                    A         B        C         D    E
# 2013-01-01 -0.675124 -0.065441 -0.68962 -0.168304  1.0
# 2013-01-02  1.332647  0.052685 -0.02279 -0.557242  1.0

# %% [markdown]
# Filling missing data

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000 -0.948619  5  5.0  1.0
# 2013-01-02  1.922248 -0.163636 -0.996819  5  1.0  1.0
# 2013-01-03  0.465146 -1.556143  0.543273  5  2.0  5.0
# 2013-01-04  0.242522  0.402289  0.931186  5  3.0  5.0

# %% [markdown]
# To get the boolean mask where values are nan

# %%
pd.isnull(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %% [markdown]
# ## Operations
#
# See the [Basic section on Binary Ops](http://pandas.pydata.org/pandas-docs/stable/basics.html#basics-binop)

# %% [markdown]
# ### Stats
#
# Operations in general exclude missing data.

# %% [markdown]
# Performing a descriptive statistic

# %%
df.mean()
# Out:
# A    0.701848
# B    0.070982
# C    0.072248
# D    5.000000
# F    3.000000
# dtype: float64

# %% [markdown]
# Same operation on the other axis

# %%
df.mean(1)
# Out:
# 2013-01-01    1.012845
# 2013-01-02    1.352359
# 2013-01-03    1.290455
# 2013-01-04    1.915199
# 2013-01-05    2.232670
# 2013-01-06    2.413134
# Freq: D, dtype: float64

# %% [markdown]
# Operating with objects that have different dimensionality and need alignment. In addition, pandas automatically broadcasts along the specified dimension.

# %%
s = pd.Series([1,3,5,np.nan,6,8], index=dates).shift(2)

# %%
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis='index')
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -0.534854 -2.556143 -0.456727  4.0  1.0
# 2013-01-04 -2.757478 -2.597711 -2.068814  2.0  0.0
# 2013-01-05 -4.224265 -4.072618 -4.539766  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %% [markdown]
# ### Apply

# %% [markdown]
# Applying functions to the data

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D     F
# 2013-01-01  0.000000  0.000000 -0.948619   5   NaN
# 2013-01-02  1.922248 -0.163636 -1.945438  10   1.0
# 2013-01-03  2.387394 -1.719778 -1.402165  15   3.0
# 2013-01-04  2.629916 -1.317489 -0.470979  20   6.0
# 2013-01-05  3.405651 -0.390107 -0.010745  25  10.0
# 2013-01-06  4.211089  0.425893  0.433488  30  15.0

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    1.922248
# B    2.483525
# C    1.928005
# D    0.000000
# F    4.000000
# dtype: float64

# %% [markdown]
# ### Histogramming
#
# See more at [Histogramming and Discretization](http://pandas.pydata.org/pandas-docs/stable/basics.html#basics-discretization)

# %%
s = pd.Series(np.random.randint(0, 7, size=10))

# %%
s
# Out:
# 0    1
# 1    0
# 2    3
# 3    3
# 4    4
# 5    5
# 6    1
# 7    2
# 8    1
# 9    2
# dtype: int64

# %%
s.value_counts()
# Out:
# 1    3
# 3    2
# 2    2
# 5    1
# 4    1
# 0    1
# dtype: int64

# %% [markdown]
# ### String Methods
#
# Series is equipped with a set of string processing methods in the str attribute that make it easy to operate on each element of the array, as in the code snippet below. Note that pattern-matching in str generally uses [regular expressions](https://docs.python.org/2/library/re.html) by default (and in some cases always uses them). See more at [Vectorized String Methods](http://pandas.pydata.org/pandas-docs/stable/text.html#text-string-methods).

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])

# %%
s.str.lower()

# %% [markdown]
# ## Merge

# %% [markdown]
# ### Concat
#
# pandas provides various facilities for easily combining together Series, DataFrame, and Panel objects with various kinds of set logic for the indexes and relational algebra functionality in the case of join / merge-type operations.
#
# See the [Merging section](http://pandas.pydata.org/pandas-docs/stable/merging.html#merging)

# %% [markdown]
# Concatenating pandas objects together with concat():

# %%
df = pd.DataFrame(np.random.randn(10, 4))

# %%
df

# %%
# break it into pieces
pieces = [df[:3], df[3:7], df[7:]]

# %%
pd.concat(pieces)
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -0.948619  5  NaN
# 2013-01-02  1.922248 -0.163636 -0.996819  5  1.0
# 2013-01-03  0.465146 -1.556143  0.543273  5  2.0
# 2013-01-04  0.242522  0.402289  0.931186  5  3.0
# 2013-01-05  0.775735  0.927382  0.460234  5  4.0
# 2013-01-06  0.805438  0.816000  0.444233  5  5.0

# %% [markdown]
# ### Join
#
# SQL style merges. See the [Database style joining](http://pandas.pydata.org/pandas-docs/stable/merging.html#merging-join)

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})

# %%
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %% [markdown]
# ### Append
#
# Append rows to a dataframe. See the [Appending](http://pandas.pydata.org/pandas-docs/stable/merging.html#merging-concatenation)

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A','B','C','D'])

# %%
df

# %%
s = df.iloc[3]

# %%
df.append(s, ignore_index=True)

# %% [markdown]
# ## Grouping
#
# By “group by” we are referring to a process involving one or more of the following steps
#
# * **Splitting** the data into groups based on some criteria
# * **Applying** a function to each group independently
# * **Combining** the results into a data structure
#
# See the [Grouping section](http://pandas.pydata.org/pandas-docs/stable/groupby.html#groupby)

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
                                    'B' : ['one', 'one', 'two', 'three','two', 'two', 'one', 'three'],
                                    'C' : np.random.randn(8),
                                     'D' : np.random.randn(8)})

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one -0.073835  0.002562
# 1  bar    one -0.414656  1.414238
# 2  foo    two  0.523676 -0.598471
# 3  bar  three  0.500749 -0.827899
# 4  foo    two -1.978023 -1.071233
# 5  bar    two -1.283217  0.311544
# 6  foo    one  1.100405 -0.481637
# 7  foo  three  0.230093 -1.462784

# %% [markdown]
# Grouping and then applying a function sum to the resulting groups.

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar -1.197124  0.897883
# foo -0.197684 -3.611565

# %%
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one   -0.414656  1.414238
#     three  0.500749 -0.827899
#     two   -1.283217  0.311544
# foo one    1.026569 -0.479076
#     three  0.230093 -1.462784
#     two   -1.454346 -1.669704

# %% [markdown]
# ## Reshaping
#
# See the sections on [Hierarchical Indexing](http://pandas.pydata.org/pandas-docs/stable/advanced.html#advanced-hierarchical) and [Reshaping](http://pandas.pydata.org/pandas-docs/stable/reshaping.html#reshaping-stacking).

# %% [markdown]
# ### Stack

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz', 'foo', 'foo', 'qux', 'qux'],
                                ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two']]))

# %%
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])

# %%
df2 = df[:4]

# %%
df2

# %% [markdown]
# The stack() method “compresses” a level in the DataFrame’s columns.

# %%
stacked = df2.stack()

# %%
stacked

# %% [markdown]
# With a “stacked” DataFrame or Series (having a MultiIndex as the index), the inverse operation of stack() is unstack(), which by default unstacks the **last level**:

# %%
stacked.unstack()

# %%
stacked.unstack(1)

# %%
stacked.unstack(0)

# %% [markdown]
# ### Pivot Tables
#
# See the section on [Pivot Tables](http://pandas.pydata.org/pandas-docs/stable/reshaping.html#reshaping-pivot).

# %%
df = pd.DataFrame({'A' : ['one', 'one', 'two', 'three'] * 3,
                                    'B' : ['A', 'B', 'C'] * 4,
                                    'C' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                                    'D' : np.random.randn(12),
                                    'E' : np.random.randn(12)})

# %%
df

# %% [markdown]
# We can produce pivot tables from this data very easily:

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])

# %% [markdown]
# ## Time Series
#
# pandas has simple, powerful, and efficient functionality for performing resampling operations during frequency conversion (e.g., converting secondly data into 5-minutely data). This is extremely common in, but not limited to, financial applications. See the [Time Series section](http://pandas.pydata.org/pandas-docs/stable/timeseries.html#timeseries)

# %%
rng = pd.date_range('1/1/2012', periods=100, freq='S')

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

# %%
ts
# Out:
# 2012-01-01 00:00:00    278
# 2012-01-01 00:00:01    200
# 2012-01-01 00:00:02     13
# 2012-01-01 00:00:03    340
# 2012-01-01 00:00:04    206
# 2012-01-01 00:00:05     45
# 2012-01-01 00:00:06    198
# 2012-01-01 00:00:07    384
# 2012-01-01 00:00:08    121
# 2012-01-01 00:00:09    404
# 2012-01-01 00:00:10    279
# 2012-01-01 00:00:11    196
# 2012-01-01 00:00:12    249
# 2012-01-01 00:00:13    478
# 2012-01-01 00:00:14    263
# 2012-01-01 00:00:15    333
# 2012-01-01 00:00:16    491
# 2012-01-01 00:00:17    491
# 2012-01-01 00:00:18     54
# 2012-01-01 00:00:19    106
# 2012-01-01 00:00:20    289
# 2012-01-01 00:00:21    444
# 2012-01-01 00:00:22    467
# 2012-01-01 00:00:23    282
# 2012-01-01 00:00:24     35
# 2012-01-01 00:00:25     71
# 2012-01-01 00:00:26     81
# 2012-01-01 00:00:27    193
# 2012-01-01 00:00:28    218
# 2012-01-01 00:00:29     46
#                       ...
# 2012-01-01 00:01:10     28
# 2012-01-01 00:01:11    117
# 2012-01-01 00:01:12    156
# 2012-01-01 00:01:13    165
# 2012-01-01 00:01:14    352
# 2012-01-01 00:01:15    119
# 2012-01-01 00:01:16    280
# 2012-01-01 00:01:17    259
# 2012-01-01 00:01:18    168
# 2012-01-01 00:01:19    230
# 2012-01-01 00:01:20    409
# 2012-01-01 00:01:21    314
# 2012-01-01 00:01:22    220
# 2012-01-01 00:01:23    444
# 2012-01-01 00:01:24    309
# 2012-01-01 00:01:25    232
# 2012-01-01 00:01:26     28
# 2012-01-01 00:01:27    102
# 2012-01-01 00:01:28    295
# 2012-01-01 00:01:29    248
# 2012-01-01 00:01:30    338
# 2012-01-01 00:01:31    308
# 2012-01-01 00:01:32    317
# 2012-01-01 00:01:33    481
# 2012-01-01 00:01:34    189
# 2012-01-01 00:01:35    320
# 2012-01-01 00:01:36     67
# 2012-01-01 00:01:37     90
# 2012-01-01 00:01:38    364
# 2012-01-01 00:01:39    170
# Freq: S, Length: 100, dtype: int64

# %%
ts.resample('5Min').sum()
# Out:
# 2012-01-01    25572
# Freq: 5T, dtype: int64

# %% [markdown]
# Time zone representation

# %%
rng = pd.date_range('3/6/2012 00:00', periods=5, freq='D')

# %%
ts = pd.Series(np.random.randn(len(rng)), rng)

# %%
ts

# %%
ts_utc = ts.tz_localize('UTC')

# %%
ts_utc

# %% [markdown]
# Convert to another time zone

# %%
ts_utc.tz_convert('US/Eastern')

# %% [markdown]
# Converting between time span representations

# %%
rng = pd.date_range('1/1/2012', periods=5, freq='M')

# %%
ts = pd.Series(np.random.randn(len(rng)), index=rng)

# %%
ts

# %%
ps = ts.to_period()

# %%
ps

# %%
ps.to_timestamp()

# %% [markdown]
# Converting between period and timestamp enables some convenient arithmetic functions to be used. In the following example, we convert a quarterly frequency with year ending in November to 9am of the end of the month following the quarter end:

# %%
prng = pd.period_range('1990Q1', '2000Q4', freq='Q-NOV')

# %%
ts = pd.Series(np.random.randn(len(prng)), prng)

# %%
ts.index = (prng.asfreq('M', 'e') + 1).asfreq('H', 's') + 9

# %%
ts.head()

# %% [markdown]
# ## Categoricals

# %% [markdown]
# Since version 0.15, pandas can include categorical data in a DataFrame. For full docs, see the [categorical introduction](http://pandas.pydata.org/pandas-docs/stable/categorical.html#categorical) and the [API documentation](http://pandas.pydata.org/pandas-docs/stable/api.html#api-categorical).

# %%
df = pd.DataFrame({"id":[1,2,3,4,5,6], "raw_grade":['a', 'b', 'b', 'a', 'a', 'e']})

# %% [markdown]
# Convert the raw grades to a categorical data type.

# %%
df["grade"] = df["raw_grade"].astype("category")

# %%
df["grade"]

# %% [markdown]
# Rename the categories to more meaningful names (assigning to Series.cat.categories is inplace!)

# %%
df["grade"].cat.categories = ["very good", "good", "very bad"]

# %% [markdown]
# Reorder the categories and simultaneously add the missing categories (methods under Series .cat return a new Series per default).

# %%
df["grade"] = df["grade"].cat.set_categories(["very bad", "bad", "medium", "good", "very good"])

# %%
df["grade"]

# %% [markdown]
# Sorting is per order in the categories, not lexical order.

# %%
df.sort_values(by="grade")

# %% [markdown]
# Grouping by a categorical column shows also empty categories.

# %%
df.groupby("grade").size()

# %% [markdown]
# ## Plotting
# [Plotting](http://pandas.pydata.org/pandas-docs/stable/visualization.html#visualization) docs.

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
ts = ts.cumsum()

# %%
ts.plot()

# %% [markdown]
# On DataFrame, plot() is a convenience to plot all of the columns with labels:

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
                  columns=['A', 'B', 'C', 'D'])

# %%
df = df.cumsum()

# %%
plt.figure(); df.plot(); plt.legend(loc='best')

# %%
df = pd.read_html()

# %% [markdown]
# ## Getting Data In/Out

# %% [markdown]
# ### CSV
# [Writing to a csv file](http://pandas.pydata.org/pandas-docs/stable/io.html#io-store-in-csv)

# %%
df.to_csv('foo.csv')

# %% [markdown]
# [Reading from a csv file](http://pandas.pydata.org/pandas-docs/stable/io.html#io-read-csv-table)

# %%
pd.read_csv('foo.csv')

# %% [markdown]
# ### HDF5
# Reading and writing to [HDFStores](http://pandas.pydata.org/pandas-docs/stable/io.html#io-hdf5)
#
# Writing to a HDF5 Store

# %%
df.to_hdf('foo.h5','df')

# %% [markdown]
# Reading from a HDF5 Store

# %%
pd.read_hdf('foo.h5','df')

# %% [markdown]
# ### Excel
#
# Reading and writing to [MS Excel](http://pandas.pydata.org/pandas-docs/stable/io.html#io-excel)
#
# Writing to an excel file

# %%
df.to_excel('foo.xlsx', sheet_name='Sheet1')

# %% [markdown]
# Reading from an excel file

# %%
pd.read_excel('foo.xlsx', 'Sheet1', index_col=None, na_values=['NA'])

# %% [markdown]
# ### Gotchas
# If you are trying an operation and you see an exception like:

# %%
if pd.Series([False, True, False]):
    print("I was true")

# %% [markdown]
# See [Comparisons](http://pandas.pydata.org/pandas-docs/stable/basics.html#basics-compare) for an explanation and what to do.
#
# See [Gotchas](http://pandas.pydata.org/pandas-docs/stable/gotchas.html#gotchas) as well.
